# %%
from utils.Dataset import MIMICDataset

# %%
dataset = MIMICDataset(max_patients=10)
# Out:
# Loading MIMIC-IV data tables...
#   - Loading patients...
#   - Loading admissions...
#   - Limited to 10 patients
#   - Filtered to 10 patients, 16 admissions
#   - Loading ICU stays...
#   - Loading diagnosis dictionary...
#   - Loading lab items dictionary...
#   - Loading procedure dictionary...
#   - Loading diagnoses...
#   - Loading procedures...
#   - Loading prescriptions...
#   - Loading lab events (filtering by hadm_id)...
#   - Loading microbiology events...
# /Users/jakeblum/Chickens-Datathon-25/utils/Dataset.py:275: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.microbiology_df = pd.read_csv(self.hosp_dir / "microbiologyevents.csv.gz", compression='gzip')
#   - ICU time-series data will be loaded on-demand...
# Indexing data for fast lookups...
#   - Indexing prescriptions...
#   - Indexing lab events...
#   - Indexing microbiology events...
#   - Preparing ICU time-series data (indexed on-demand)...
# Data loading complete!

# %%
type(dataset)
# Out:
# utils.Dataset.MIMICDataset

# %%
patients = dataset.get_all_patients()
len(patients)
# Out:
# 10

# %%
for patient in patients:
    print(f"  - Patient {patient.subject_id}: {len(patient.admissions)} admissions")
# Out:
#   - Patient 10000032: 4 admissions
#   - Patient 10000068: 1 admissions
#   - Patient 10000084: 2 admissions
#   - Patient 10000108: 1 admissions
#   - Patient 10000117: 2 admissions
#   - Patient 10000161: 1 admissions
#   - Patient 10000248: 1 admissions
#   - Patient 10000280: 1 admissions
#   - Patient 10000560: 1 admissions
#   - Patient 10000635: 2 admissions

# %%
patient = patients[0]

hadm_id = patient.admissions[0].hadm_id

timeline = dataset.get_admission_timeline(hadm_id)
timeline
# Out:
#              timestamp  event_type  \
# 0  2180-05-06 22:23:00   Admission
# 1  2180-05-06 22:23:00   Diagnosis
# 2  2180-05-06 22:23:00   Diagnosis
# 3  2180-05-06 22:23:00   Diagnosis
# 4  2180-05-06 22:23:00   Diagnosis
# 5  2180-05-06 22:23:00   Diagnosis
# 6  2180-05-06 22:23:00   Diagnosis
# 7  2180-05-06 22:23:00   Diagnosis
# 8  2180-05-06 22:23:00   Diagnosis
# 9  2180-05-07 00:00:00   Procedure
# 10 2180-05-07 00:00:00  Medication
# 11 2180-05-07 00:00:00  Medication
# 12 2180-05-07 00:00:00  Medication
# 13 2180-05-07 00:10:00  Lab Result
# 14 2180-05-07 01:00:00  Medication
# 15 2180-05-07 01:00:00  Medication
# 16 2180-05-07 01:00:00  Medication
# 17 2180-05-07 01:00:00  Medication
# 18 2180-05-07 01:00:00  Medication
# 19 2180-05-07 01:00:00  Medication
# 20 2180-05-07 01:00:00  Medication
# 21 2180-05-07 01:00:00  Medication
# 22 2180-05-07 02:00:00  Medication
# 23 2180-05-07 05:05:00  Lab Result
# 24 2180-05-07 05:05:00  Lab Result
# 25 2180-05-07 05:05:00  Lab Result
# 26 2180-05-07 05:05:00  Lab Result
# 27 2180-05-07 05:05:00  Lab Result
# 28 2180-05-07 05:05:00  Lab Result
# 29 2180-05-07 05:05:00  Lab Result
# 30 2180-05-07 05:05:00  Lab Result
# 31 2180-05-07 05:05:00  Lab Result
# 32 2180-05-07 05:05:00  Lab Result
# 33 2180-05-07 05:05:00  Lab Result
# 34 2180-05-07 10:11:00  Lab Result
# 35 2180-05-07 10:11:00  Lab Result
# 36 2180-05-07 10:11:00  Lab Result
# 37 2180-05-07 10:11:00  Lab Result
# 38 2180-05-07 10:11:00  Lab Result
# 39 2180-05-07 10:11:00  Lab Result
# 40 2180-05-07 10:11:00  Lab Result
# 41 2180-05-07 17:15:00   Discharge
# 42 2180-05-08 08:00:00  Medication
# 43 2180-05-08 08:00:00  Medication
#
#                                           description  \
# 0                 Admitted via TRANSFER FROM HOSPITAL
# 1                       Posttraumatic stress disorder
# 2                       Bipolar disorder, unspecified
# 3   Chronic airway obstruction, not elsewhere clas...
# 4                     Personal history of tobacco use
# 5       Cirrhosis of liver without mention of alcohol
# 6                                       Other ascites
# 7                                 Portal hypertension
# 8   Unspecified viral hepatitis C without hepatic ...
# 9                     Percutaneous abdominal drainage
# 10                                Heparin - 5000 UNIT
# 11                 Sodium Chloride 0.9%  Flush - 3 mL
# 12            Influenza Vaccine Quadrivalent - 0.5 mL
# 13                       Urobilinogen: 4.0 (abnormal)
# 14                         Albuterol Inhaler - 2 PUFF
# 15                             Nicotine Patch - 14 mg
# 16          Emtricitabine-Tenofovir (Truvada) - 1 TAB
# 17                             Spironolactone - 50 mg
# 18                               Raltegravir - 400 mg
# 19                        Potassium Chloride - 40 mEq
# 20                                 Furosemide - 20 mg
# 21                             Acetaminophen - 500 mg
# 22                    Ipratropium Bromide Neb - 1 NEB
# 23                                PT: 16.6 (abnormal)
# 24                     Urea Nitrogen: 25.0 (abnormal)
# 25                         Creatinine: 0.3 (abnormal)
# 26                     Calcium, Total: 7.8 (abnormal)
# 27   Asparate Aminotransferase (AST): 98.0 (abnormal)
# 28    Alanine Aminotransferase (ALT): 88.0 (abnormal)
# 29                            INR(PT): 1.5 (abnormal)
# 30                    Red Blood Cells: 3.8 (abnormal)
# 31                    Platelet Count: 71.0 (abnormal)
# 32                               MCV: 99.0 (abnormal)
# 33                               MCH: 33.4 (abnormal)
# 34                    RBC, Ascites: 8800.0 (abnormal)
# 35   Total Nucleated Cells, Ascites: 300.0 (abnormal)
# 36                        Eosinophils: 1.0 (abnormal)
# 37                       Lymphocytes: 49.0 (abnormal)
# 38                        Macrophage: 35.0 (abnormal)
# 39                   Mesothelial Cell: 2.0 (abnormal)
# 40                             Polys: 13.0 (abnormal)
# 41                                 Discharged to HOME
# 42                                 Furosemide - 40 mg
# 43                             Spironolactone - 50 mg
#
#                                               details
# 0   {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 1   {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 2   {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 3   {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 4   {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 5   {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 6   {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 7   {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 8   {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 9   {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 10  {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 11  {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 12  {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 13  {'labevent_id': 122, 'subject_id': 10000032, '...
# 14  {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 15  {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 16  {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 17  {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 18  {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 19  {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 20  {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 21  {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 22  {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 23  {'labevent_id': 140, 'subject_id': 10000032, '...
# 24  {'labevent_id': 156, 'subject_id': 10000032, '...
# 25  {'labevent_id': 150, 'subject_id': 10000032, '...
# 26  {'labevent_id': 148, 'subject_id': 10000032, '...
# 27  {'labevent_id': 145, 'subject_id': 10000032, '...
# 28  {'labevent_id': 142, 'subject_id': 10000032, '...
# 29  {'labevent_id': 139, 'subject_id': 10000032, '...
# 30  {'labevent_id': 137, 'subject_id': 10000032, '...
# 31  {'labevent_id': 135, 'subject_id': 10000032, '...
# 32  {'labevent_id': 134, 'subject_id': 10000032, '...
# 33  {'labevent_id': 132, 'subject_id': 10000032, '...
# 34  {'labevent_id': 163, 'subject_id': 10000032, '...
# 35  {'labevent_id': 164, 'subject_id': 10000032, '...
# 36  {'labevent_id': 157, 'subject_id': 10000032, '...
# 37  {'labevent_id': 158, 'subject_id': 10000032, '...
# 38  {'labevent_id': 159, 'subject_id': 10000032, '...
# 39  {'labevent_id': 160, 'subject_id': 10000032, '...
# 40  {'labevent_id': 162, 'subject_id': 10000032, '...
# 41  {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 42  {'subject_id': 10000032, 'hadm_id': 22595853, ...
# 43  {'subject_id': 10000032, 'hadm_id': 22595853, ...

# %%
lab_summary = dataset.get_lab_results_summary(hadm_id, include_normal=True)
lab_summary['all']
# Out:
#     labevent_id  subject_id     hadm_id  specimen_id  itemid  \
# 0           111    10000032  22595853.0     31810588   51464
# 1           129    10000032  22595853.0     61728080   51092
# 2           128    10000032  22595853.0     61728080   51090
# 3           127    10000032  22595853.0     61728080   51087
# 4           125    10000032  22595853.0     61728080   51075
# 5           124    10000032  22595853.0     61728080   51074
# 6           123    10000032  22595853.0     61728080   51071
# 7           122    10000032  22595853.0     31810588   51514
# 8           121    10000032  22595853.0     31810588   51508
# 9           126    10000032  22595853.0     61728080   51079
# 10          119    10000032  22595853.0     31810588   51498
# 11          118    10000032  22595853.0     31810588   51492
# 12          117    10000032  22595853.0     31810588   51491
# 13          116    10000032  22595853.0     31810588   51487
# 14          115    10000032  22595853.0     31810588   51486
# 15          114    10000032  22595853.0     31810588   51484
# 16          113    10000032  22595853.0     31810588   51478
# 17          112    10000032  22595853.0     31810588   51466
# 18          120    10000032  22595853.0     31810588   51506
# 19          146    10000032  22595853.0     86271148   50882
# 20          147    10000032  22595853.0     86271148   50885
# 21          148    10000032  22595853.0     86271148   50893
# 22          149    10000032  22595853.0     86271148   50902
# 23          150    10000032  22595853.0     86271148   50912
# 24          155    10000032  22595853.0     86271148   50983
# 25          152    10000032  22595853.0     86271148   50960
# 26          153    10000032  22595853.0     86271148   50970
# 27          154    10000032  22595853.0     86271148   50971
# 28          156    10000032  22595853.0     86271148   51006
# 29          145    10000032  22595853.0     86271148   50878
# 30          151    10000032  22595853.0     86271148   50931
# 31          144    10000032  22595853.0     86271148   50868
# 32          139    10000032  22595853.0     61805039   51237
# 33          142    10000032  22595853.0     86271148   50861
# 34          130    10000032  22595853.0     16204564   51221
# 35          143    10000032  22595853.0     86271148   50863
# 36          132    10000032  22595853.0     16204564   51248
# 37          133    10000032  22595853.0     16204564   51249
# 38          134    10000032  22595853.0     16204564   51250
# 39          135    10000032  22595853.0     16204564   51265
# 40          131    10000032  22595853.0     16204564   51222
# 41          137    10000032  22595853.0     16204564   51279
# 42          138    10000032  22595853.0     16204564   51301
# 43          140    10000032  22595853.0     61805039   51274
# 44          141    10000032  22595853.0     61805039   51275
# 45          136    10000032  22595853.0     16204564   51277
# 46          166    10000032  22595853.0     80754202   50843
# 47          157    10000032  22595853.0     53479500   51114
# 48          158    10000032  22595853.0     53479500   51116
# 49          159    10000032  22595853.0     53479500   51117
# 50          160    10000032  22595853.0     53479500   51118
# 51          161    10000032  22595853.0     53479500   51120
# 52          162    10000032  22595853.0     53479500   51125
# 53          163    10000032  22595853.0     53479500   51127
# 54          164    10000032  22595853.0     53479500   52065
# 55          165    10000032  22595853.0     80754202   50835
# 56          167    10000032  22595853.0     80754202   50849
#
#    order_provider_id           charttime            storetime  value  \
# 0                NaN 2180-05-07 00:10:00  2180-05-07 00:40:00    NaN
# 1                NaN 2180-05-07 00:10:00  2180-05-07 00:45:00    POS
# 2                NaN 2180-05-07 00:10:00  2180-05-07 00:45:00    NEG
# 3                NaN 2180-05-07 00:10:00                  NaN    NaN
# 4                NaN 2180-05-07 00:10:00  2180-05-07 00:45:00    NEG
# 5                NaN 2180-05-07 00:10:00  2180-05-07 00:45:00    NEG
# 6                NaN 2180-05-07 00:10:00  2180-05-07 00:45:00    NEG
# 7                NaN 2180-05-07 00:10:00  2180-05-07 00:40:00      4
# 8                NaN 2180-05-07 00:10:00  2180-05-07 00:40:00    NaN
# 9                NaN 2180-05-07 00:10:00  2180-05-07 00:45:00    NEG
# 10               NaN 2180-05-07 00:10:00  2180-05-07 00:40:00  1.033
# 11               NaN 2180-05-07 00:10:00  2180-05-07 00:40:00     30
# 12               NaN 2180-05-07 00:10:00  2180-05-07 00:40:00    6.0
# 13               NaN 2180-05-07 00:10:00  2180-05-07 00:40:00    NaN
# 14               NaN 2180-05-07 00:10:00  2180-05-07 00:40:00    NaN
# 15               NaN 2180-05-07 00:10:00  2180-05-07 00:40:00    NaN
# 16               NaN 2180-05-07 00:10:00  2180-05-07 00:40:00    NaN
# 17               NaN 2180-05-07 00:10:00  2180-05-07 00:40:00    NaN
# 18               NaN 2180-05-07 00:10:00  2180-05-07 00:40:00    NaN
# 19               NaN 2180-05-07 05:05:00  2180-05-07 07:03:00     28
# 20               NaN 2180-05-07 05:05:00  2180-05-07 07:03:00    1.3
# 21               NaN 2180-05-07 05:05:00  2180-05-07 07:03:00    7.8
# 22               NaN 2180-05-07 05:05:00  2180-05-07 07:03:00    105
# 23               NaN 2180-05-07 05:05:00  2180-05-07 07:03:00    0.3
# 24               NaN 2180-05-07 05:05:00  2180-05-07 07:03:00    137
# 25               NaN 2180-05-07 05:05:00  2180-05-07 07:03:00    1.7
# 26               NaN 2180-05-07 05:05:00  2180-05-07 07:03:00    3.6
# 27               NaN 2180-05-07 05:05:00  2180-05-07 07:03:00    4.5
# 28               NaN 2180-05-07 05:05:00  2180-05-07 07:03:00     25
# 29               NaN 2180-05-07 05:05:00  2180-05-07 07:03:00     98
# 30               NaN 2180-05-07 05:05:00  2180-05-07 07:03:00    ___
# 31               NaN 2180-05-07 05:05:00  2180-05-07 07:03:00      9
# 32               NaN 2180-05-07 05:05:00  2180-05-07 06:43:00    1.5
# 33               NaN 2180-05-07 05:05:00  2180-05-07 07:03:00     88
# 34               NaN 2180-05-07 05:05:00  2180-05-07 06:22:00   37.6
# 35               NaN 2180-05-07 05:05:00  2180-05-07 07:03:00    103
# 36               NaN 2180-05-07 05:05:00  2180-05-07 06:22:00   33.4
# 37               NaN 2180-05-07 05:05:00  2180-05-07 06:22:00   33.8
# 38               NaN 2180-05-07 05:05:00  2180-05-07 06:22:00     99
# 39               NaN 2180-05-07 05:05:00  2180-05-07 06:22:00     71
# 40               NaN 2180-05-07 05:05:00  2180-05-07 06:22:00   12.7
# 41               NaN 2180-05-07 05:05:00  2180-05-07 06:22:00   3.80
# 42               NaN 2180-05-07 05:05:00  2180-05-07 06:22:00    4.2
# 43               NaN 2180-05-07 05:05:00  2180-05-07 06:43:00   16.6
# 44               NaN 2180-05-07 05:05:00  2180-05-07 06:43:00   32.3
# 45               NaN 2180-05-07 05:05:00  2180-05-07 06:22:00   15.3
# 46               NaN 2180-05-07 10:11:00  2180-05-07 12:50:00     31
# 47               NaN 2180-05-07 10:11:00  2180-05-07 12:17:00      1
# 48               NaN 2180-05-07 10:11:00  2180-05-07 12:17:00     49
# 49               NaN 2180-05-07 10:11:00  2180-05-07 12:17:00     35
# 50               NaN 2180-05-07 10:11:00  2180-05-07 12:17:00      2
# 51               NaN 2180-05-07 10:11:00  2180-05-07 12:17:00      0
# 52               NaN 2180-05-07 10:11:00  2180-05-07 12:17:00     13
# 53               NaN 2180-05-07 10:11:00  2180-05-07 11:40:00   8800
# 54               NaN 2180-05-07 10:11:00  2180-05-07 11:40:00    300
# 55               NaN 2180-05-07 10:11:00  2180-05-07 12:50:00    NaN
# 56               NaN 2180-05-07 10:11:00  2180-05-07 12:50:00    0.5
#
#     valuenum  ... ref_range_lower  ref_range_upper      flag priority  \
# 0        NaN  ...             NaN              NaN       NaN  ROUTINE
# 1        NaN  ...             NaN              NaN       NaN  ROUTINE
# 2        NaN  ...             NaN              NaN       NaN  ROUTINE
# 3        NaN  ...             NaN              NaN       NaN  ROUTINE
# 4        NaN  ...             NaN              NaN       NaN  ROUTINE
# 5        NaN  ...             NaN              NaN       NaN  ROUTINE
# 6        NaN  ...             NaN              NaN       NaN  ROUTINE
# 7      4.000  ...           0.200            1.000  abnormal  ROUTINE
# 8        NaN  ...             NaN              NaN       NaN  ROUTINE
# 9        NaN  ...             NaN              NaN       NaN  ROUTINE
# 10     1.033  ...           1.001            1.035       NaN  ROUTINE
# 11    30.000  ...             NaN              NaN       NaN  ROUTINE
# 12     6.000  ...           5.000            8.000       NaN  ROUTINE
# 13       NaN  ...             NaN              NaN       NaN  ROUTINE
# 14       NaN  ...             NaN              NaN       NaN  ROUTINE
# 15       NaN  ...             NaN              NaN       NaN  ROUTINE
# 16       NaN  ...             NaN              NaN       NaN  ROUTINE
# 17       NaN  ...             NaN              NaN       NaN  ROUTINE
# 18       NaN  ...             NaN              NaN       NaN  ROUTINE
# 19    28.000  ...          22.000           32.000       NaN  ROUTINE
# 20     1.300  ...           0.000            1.500       NaN  ROUTINE
# 21     7.800  ...           8.400           10.300  abnormal  ROUTINE
# 22   105.000  ...          96.000          108.000       NaN  ROUTINE
# 23     0.300  ...           0.400            1.100  abnormal  ROUTINE
# 24   137.000  ...         133.000          145.000       NaN  ROUTINE
# 25     1.700  ...           1.600            2.600       NaN  ROUTINE
# 26     3.600  ...           2.700            4.500       NaN  ROUTINE
# 27     4.500  ...           3.300            5.100       NaN  ROUTINE
# 28    25.000  ...           6.000           20.000  abnormal  ROUTINE
# 29    98.000  ...           0.000           40.000  abnormal  ROUTINE
# 30    99.000  ...          70.000          100.000       NaN  ROUTINE
# 31     9.000  ...           8.000           20.000       NaN  ROUTINE
# 32     1.500  ...           0.900            1.100  abnormal  ROUTINE
# 33    88.000  ...           0.000           40.000  abnormal  ROUTINE
# 34    37.600  ...          36.000           48.000       NaN  ROUTINE
# 35   103.000  ...          35.000          105.000       NaN  ROUTINE
# 36    33.400  ...          27.000           32.000  abnormal  ROUTINE
# 37    33.800  ...          31.000           35.000       NaN  ROUTINE
# 38    99.000  ...          82.000           98.000  abnormal  ROUTINE
# 39    71.000  ...         150.000          440.000  abnormal  ROUTINE
# 40    12.700  ...          12.000           16.000       NaN  ROUTINE
# 41     3.800  ...           4.200            5.400  abnormal  ROUTINE
# 42     4.200  ...           4.000           11.000       NaN  ROUTINE
# 43    16.600  ...           9.400           12.500  abnormal  ROUTINE
# 44    32.300  ...          25.000           36.500       NaN  ROUTINE
# 45    15.300  ...          10.500           15.500       NaN  ROUTINE
# 46    31.000  ...             NaN              NaN       NaN     STAT
# 47     1.000  ...           0.000            0.000  abnormal     STAT
# 48    49.000  ...           0.000            0.000  abnormal     STAT
# 49    35.000  ...           0.000            0.000  abnormal     STAT
# 50     2.000  ...           0.000            0.000  abnormal     STAT
# 51     0.000  ...           0.000            0.000       NaN     STAT
# 52    13.000  ...           0.000            0.000  abnormal     STAT
# 53  8800.000  ...           0.000            0.000  abnormal     STAT
# 54   300.000  ...           0.000            0.000  abnormal     STAT
# 55       NaN  ...             NaN              NaN       NaN     STAT
# 56     0.500  ...             NaN              NaN       NaN     STAT
#
#                                              comments  \
# 0                                                NEG.
# 1   OPIATE IMMUNOASSAY SCREEN DOES NOT DETECT SYNT...
# 2   METHADONE ASSAY DETECTS ONLY METHADONE (NOT OT...
# 3                                             RANDOM.
# 4   BENZODIAZEPINE IMMUNOASSAY SCREEN DOES NOT DET...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                             Yellow.
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                               NEG.
# 14                                               NEG.
# 15                                               NEG.
# 16                                               NEG.
# 17                                               NEG.
# 18                                              Hazy.
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30  IF FASTING, 70-100 NORMAL, >125 PROVISIONAL DI...
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                     LESS THAN 1.0.
# 56                                                NaN
#
#                               label    category  flag_str is_positive  \
# 0                         Bilirubin  Hematology       NAN       False
# 1              Opiate Screen, Urine   Chemistry       NAN       False
# 2                  Methadone, Urine   Chemistry       NAN       False
# 3        Length of Urine Collection   Chemistry       NAN       False
# 4      Benzodiazepine Screen, Urine   Chemistry       NAN       False
# 5         Barbiturate Screen, Urine   Chemistry       NAN       False
# 6         Amphetamine Screen, Urine   Chemistry       NAN       False
# 7                      Urobilinogen  Hematology  ABNORMAL        True
# 8                       Urine Color  Hematology       NAN       False
# 9                    Cocaine, Urine   Chemistry       NAN       False
# 10                 Specific Gravity  Hematology       NAN       False
# 11                          Protein  Hematology       NAN       False
# 12                               pH  Hematology       NAN       False
# 13                          Nitrite  Hematology       NAN       False
# 14                       Leukocytes  Hematology       NAN       False
# 15                           Ketone  Hematology       NAN       False
# 16                          Glucose  Hematology       NAN       False
# 17                            Blood  Hematology       NAN       False
# 18                 Urine Appearance  Hematology       NAN       False
# 19                      Bicarbonate   Chemistry       NAN       False
# 20                 Bilirubin, Total   Chemistry       NAN       False
# 21                   Calcium, Total   Chemistry  ABNORMAL        True
# 22                         Chloride   Chemistry       NAN       False
# 23                       Creatinine   Chemistry  ABNORMAL        True
# 24                           Sodium   Chemistry       NAN       False
# 25                        Magnesium   Chemistry       NAN       False
# 26                        Phosphate   Chemistry       NAN       False
# 27                        Potassium   Chemistry       NAN       False
# 28                    Urea Nitrogen   Chemistry  ABNORMAL        True
# 29  Asparate Aminotransferase (AST)   Chemistry  ABNORMAL        True
# 30                          Glucose   Chemistry       NAN       False
# 31                        Anion Gap   Chemistry       NAN       False
# 32                          INR(PT)  Hematology  ABNORMAL        True
# 33   Alanine Aminotransferase (ALT)   Chemistry  ABNORMAL        True
# 34                       Hematocrit  Hematology       NAN       False
# 35             Alkaline Phosphatase   Chemistry       NAN       False
# 36                              MCH  Hematology  ABNORMAL        True
# 37                             MCHC  Hematology       NAN       False
# 38                              MCV  Hematology  ABNORMAL        True
# 39                   Platelet Count  Hematology  ABNORMAL        True
# 40                       Hemoglobin  Hematology       NAN       False
# 41                  Red Blood Cells  Hematology  ABNORMAL        True
# 42                White Blood Cells  Hematology       NAN       False
# 43                               PT  Hematology  ABNORMAL        True
# 44                              PTT  Hematology       NAN       False
# 45                              RDW  Hematology       NAN       False
# 46   Lactate Dehydrogenase, Ascites   Chemistry       NAN       False
# 47                      Eosinophils  Hematology  ABNORMAL        True
# 48                      Lymphocytes  Hematology  ABNORMAL        True
# 49                       Macrophage  Hematology  ABNORMAL        True
# 50                 Mesothelial Cell  Hematology  ABNORMAL        True
# 51                        Monocytes  Hematology       NAN       False
# 52                            Polys  Hematology  ABNORMAL        True
# 53                     RBC, Ascites  Hematology  ABNORMAL        True
# 54   Total Nucleated Cells, Ascites  Hematology  ABNORMAL        True
# 55                 Albumin, Ascites   Chemistry       NAN       False
# 56           Total Protein, Ascites   Chemistry       NAN       False
#
#     is_negative
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7         False
# 8          True
# 9          True
# 10         True
# 11         True
# 12         True
# 13         True
# 14         True
# 15         True
# 16         True
# 17         True
# 18         True
# 19         True
# 20         True
# 21        False
# 22         True
# 23        False
# 24         True
# 25         True
# 26         True
# 27         True
# 28        False
# 29        False
# 30         True
# 31         True
# 32        False
# 33        False
# 34         True
# 35         True
# 36        False
# 37         True
# 38        False
# 39        False
# 40         True
# 41        False
# 42         True
# 43        False
# 44         True
# 45         True
# 46         True
# 47        False
# 48        False
# 49        False
# 50        False
# 51         True
# 52        False
# 53        False
# 54        False
# 55         True
# 56         True
#
# [57 rows x 21 columns]

# %%
discharge_meds = dataset.get_discharge_medications(hadm_id)
discharge_meds.head()
# Out:
#    subject_id   hadm_id  pharmacy_id       poe_id  poe_seq order_provider_id  \
# 0    10000032  22595853     48214508  10000032-39     39.0            P23SJA
# 1    10000032  22595853     73243129  10000032-33     33.0            P23SJA
# 2    10000032  22595853     85199369  10000032-34     34.0            P23SJA
# 3    10000032  22595853     12775705  10000032-55     55.0            P85UQ1
# 4    10000032  22595853     86768272  10000032-32     32.0            P23SJA
#
#             starttime            stoptime drug_type  \
# 0 2180-05-07 01:00:00 2180-05-07 22:00:00      MAIN
# 1 2180-05-07 01:00:00 2180-05-07 22:00:00      MAIN
# 2 2180-05-07 01:00:00 2180-05-07 22:00:00      MAIN
# 3 2180-05-08 08:00:00 2180-05-07 22:00:00      MAIN
# 4 2180-05-07 00:00:00 2180-05-07 22:00:00      MAIN
#
#                                 drug  ...     gsn           ndc  \
# 0                      Acetaminophen  ...  004490  9.041989e+08
# 1                  Albuterol Inhaler  ...  028090  1.730682e+08
# 2  Emtricitabine-Tenofovir (Truvada)  ...  057883  6.195807e+10
# 3                         Furosemide  ...  008209  5.107901e+10
# 4                            Heparin  ...  006549  6.332303e+10
#
#                prod_strength form_rx dose_val_rx dose_unit_rx form_val_disp  \
# 0               500mg Tablet     NaN         500           mg             1
# 1                8 g Inhaler     NaN           2         PUFF          0.02
# 2           200-300mg Tablet     NaN           1          TAB             1
# 3                40mg Tablet     NaN          40           mg             1
# 4  5000 Units / mL- 1mL Vial     NaN        5000         UNIT             1
#
#   form_unit_disp doses_per_24_hrs  route
# 0            TAB              NaN  PO/NG
# 1            INH              NaN     IH
# 2            TAB              1.0     PO
# 3            TAB              1.0  PO/NG
# 4             mL              3.0     SC
#
# [5 rows x 21 columns]
